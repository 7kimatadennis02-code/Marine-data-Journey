# %% [markdown]
# # Day 1 - python Setup and First Run
# **Date:** April 1, 2026
# **Phase:** 1 - Python Foundations
# **Objective:** Setup environment and confirm everything works

# %% [markdown]
# ## Step 1 - Confirm python Environment

# %%
import pandas
import numpy
import matplotlib
import seaborn

print("All libraries loaded successfully")
print(f"pandas version: {pandas.__version__}")
print(f"numpy version: {numpy.__version__}")
print(f"matplotlib version: {matplotlib.__version__}")
print(f"seaborn version: {seaborn.__version__}")
# Out:
# All libraries loaded successfully
# pandas version: 2.3.1
# numpy version: 2.3.1
# matplotlib version: 3.10.0
# seaborn version: 0.13.2

# %% [markdown]
# ## Step 2 - First Python output

# %%
print("My 60- day data journey starts today")
print("Background: Coastal and Marine Resource Management")
print("Goal: Python, SQL, GIS and R for conservation work")
# Out:
# My 60- day data journey starts today
# Background: Coastal and Marine Resource Management
# Goal: Python, SQL, GIS and R for conservation work

# %% [markdown]
# ## Reflection
# - Environment set up successfully on Intel Macbook with Monterey
# - Miniconda used instead of Anaconda due to compatibility
# - All core libraries confirmed working
# - Ready for Day 2
# ```
#
# ___
